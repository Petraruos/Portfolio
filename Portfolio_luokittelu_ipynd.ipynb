# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('seaborn-pastel')

# %%
df = pd.read_csv('http://taanila.fi/sales_data_sample.csv', encoding = 'cp1252')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.rename(columns = {'PRICEEACH': 'yksikköhinta'}, inplace = True)
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  yksikköhinta  ORDERLINENUMBER    SALES  \
# 0        10107               30         95.70                2  2871.00
# 1        10121               34         81.35                5  2765.90
# 2        10134               41         94.74                2  3884.34
# 3        10145               45         83.26                6  3746.70
# 4        10159               49        100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
bins = [50, 60, 70, 80, 90, 100]

df['Hinnat'] = pd.cut(df['yksikköhinta'], bins = bins)

df1 = pd.crosstab(df['Hinnat'], 'lkm')

df1.columns.name = ''

n = df1['lkm'].sum()
df1['%'] = df1/n*100

df1.index = df1.index.astype(str)
df1.loc['Yhteensä'] = df1.sum()

df1.style.format({'%': '{:.1f} %'})
# Out:
# <style  type="text/css" >
# </style><table id="T_8c4552be_30d8_11ea_a8a0_f48c50eed990" ><thead>    <tr>        <th class="index_name level0" ></th>        <th class="col_heading level0 col0" >lkm</th>        <th class="col_heading level0 col1" >%</th>    </tr>    <tr>        <th class="index_name level0" >Hinnat</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c4552be_30d8_11ea_a8a0_f48c50eed990level0_row0" class="row_heading level0 row0" >(50, 60]</th>
#                         <td id="T_8c4552be_30d8_11ea_a8a0_f48c50eed990row0_col0" class="data row0 col0" >212</td>
#                         <td id="T_8c4552be_30d8_11ea_a8a0_f48c50eed990row0_col1" class="data row0 col1" >8.2 %</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4552be_30d8_11ea_a8a0_f48c50eed990level0_row1" class="row_heading level0 row1" >(60, 70]</th>
# ...

# %%
ax1 = df['yksikköhinta'].hist(bins=bins)
ax1.set_xlabel('yksikköhinta')
ax1.set_ylabel('Lukumäärä')
# Out:
# Text(0, 0.5, 'Lukumäärä')
