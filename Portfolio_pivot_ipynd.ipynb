# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('http://taanila.fi/sales_data_sample.csv', encoding = 'cp1252')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.pivot_table(values = 'SALES', index = 'YEAR_ID')
# Out:
#                SALES
# YEAR_ID
# 2003     3516.979540
# 2004     3512.388550
# 2005     3747.880146

# %%
df[df['YEAR_ID']==2005].pivot_table(values = 'SALES', 
                index = 'COUNTRY').sort_values(by = 'SALES', ascending = False)
# Out:
#                  SALES
# COUNTRY
# Denmark    8670.956667
# UK         4533.645556
# Austria    4014.721176
# Sweden     3950.840000
# USA        3910.210184
# Japan      3874.534000
# France     3796.193750
# Canada     3743.663333
# Spain      3671.889551
# Australia  3374.231860
# Finland    3338.202895
# Belgium    3130.013750
# Italy      2964.995714
# Singapore  2254.393333

# %%
ax = df[df['YEAR_ID']==2005].pivot_table(values='SALES', 
                index='COUNTRY').sort_values(by = 'SALES').plot.barh(legend=False)

ax.set_xlabel('Maakohtaiset myynnit')
# Out:
# Text(0.5, 0, 'Maakohtaiset myynnit')

# %%
df.pivot_table(values = 'SALES', index = ['COUNTRY', 'YEAR_ID'])
# Out:
#                            SALES
# COUNTRY     YEAR_ID
# Australia   2003     3287.460390
#             2004     3575.333538
#             2005     3374.231860
# Austria     2003     3158.380000
#             2004     4307.865833
#             2005     4014.721176
# Belgium     2003     1674.230000
#             2004     3479.306522
#             2005     3130.013750
# Canada      2003     3640.633333
#             2004     2951.654130
#             2005     3743.663333
# Denmark     2003     3673.804444
#             2004     3649.441212
#             2005     8670.956667
# Finland     2003     3473.578437
#             2004     4162.531364
#             2005     3338.202895
# France      2003     3594.958851
#             2004     3406.126994
#             2005     3796.193750
# Germany     2003     3335.871905
#             2004     3668.750732
# Ireland     2004     3609.776875
# Italy       2003     3202.926591
#             2004     3495.192727
# ...

# %%
df.pivot_table(values = 'SALES', index = 'COUNTRY', 
               columns = 'YEAR_ID').style.format('{:.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_2e8970dc_3134_11ea_b62a_f48c50eed990" ><thead>    <tr>        <th class="index_name level0" >YEAR_ID</th>        <th class="col_heading level0 col0" >2003</th>        <th class="col_heading level0 col1" >2004</th>        <th class="col_heading level0 col2" >2005</th>    </tr>    <tr>        <th class="index_name level0" >COUNTRY</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e8970dc_3134_11ea_b62a_f48c50eed990level0_row0" class="row_heading level0 row0" >Australia</th>
#                         <td id="T_2e8970dc_3134_11ea_b62a_f48c50eed990row0_col0" class="data row0 col0" >3287.46</td>
#                         <td id="T_2e8970dc_3134_11ea_b62a_f48c50eed990row0_col1" class="data row0 col1" >3575.33</td>
# ...

# %%
df1 = df[df['YEAR_ID']==2003].pivot_table(values = 'SALES', 
            index = 'COUNTRY', aggfunc = ['mean', 'median', 'min', 'max', 'std', 'count'])
df1.columns=['Keskiarvo','Mediaani','Pienin','Suurin','Keskihajonta','Lukumäärä']
df1.style.format({'Mean':'{:.2f}','Median':'{:.2f}','Min':'{:.2f}','Max':'{:.2f}',
                  'Stdev':'{:.2f}','Count':'{:.0f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_b6463f24_3134_11ea_8457_f48c50eed990" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Keskiarvo</th>        <th class="col_heading level0 col1" >Mediaani</th>        <th class="col_heading level0 col2" >Pienin</th>        <th class="col_heading level0 col3" >Suurin</th>        <th class="col_heading level0 col4" >Keskihajonta</th>        <th class="col_heading level0 col5" >Lukumäärä</th>    </tr>    <tr>        <th class="index_name level0" >COUNTRY</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6463f24_3134_11ea_8457_f48c50eed990level0_row0" class="row_heading level0 row0" >Australia</th>
# ...

# %%
df2 = df1[df1.index.str.contains('S')]
df2.style.format({'Mean':'{:.2f}','Median':'{:.2f}','Min':'{:.2f}','Max':'{:.2f}',
                  'Standard dev.':'{:.2f}','Count':'{:.0f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_df93bb0c_3134_11ea_b02d_f48c50eed990" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Keskiarvo</th>        <th class="col_heading level0 col1" >Mediaani</th>        <th class="col_heading level0 col2" >Pienin</th>        <th class="col_heading level0 col3" >Suurin</th>        <th class="col_heading level0 col4" >Keskihajonta</th>        <th class="col_heading level0 col5" >Lukumäärä</th>    </tr>    <tr>        <th class="index_name level0" >COUNTRY</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df93bb0c_3134_11ea_b02d_f48c50eed990level0_row0" class="row_heading level0 row0" >Singapore</th>
# ...
